# %%
# !nvidia-smi
# Out:
# Fri Sep 29 21:27:49 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 515.43.04    Driver Version: 515.43.04    CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-PCI...  On   | 00000000:12:00.0 Off |                    0 |
# | N/A   24C    P0    37W / 250W |   4173MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import platform 
print(platform. python_version())
# Out:
# 3.11.4

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
from ultralytics import YOLO

from IPython.display import display, Image
# Out:
# Ultralytics YOLOv8.0.162 🚀 Python-3.11.4 torch-2.0.1 CUDA:0 (NVIDIA A100-PCIE-40GB, 40390MiB)
# Setup complete ✅ (48 CPUs, 1509.9 GB RAM, 24.8/1786.5 GB disk)

# %%
model = YOLO('yolov8x-cls.pt') # m, s, n, l
# Out:
# ...
# 100%|██████████████████████████████████████| 71.7M/71.7M [00:01<00:00, 45.4MB/s]

# %%
# Train the model
results = model.train(data='/cluster/home/ammaa/Downloads/Ammars/Models/PIM/FGVC-Multi/Split_500/', batch=64, epochs=100, imgsz=384, device="cuda:0", cache=True)


##########
# Out:
# New https://pypi.org/project/ultralytics/8.0.189 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.162 🚀 Python-3.11.4 torch-2.0.1 CUDA:0 (NVIDIA A100-PCIE-40GB, 40390MiB)
# ...

# %%
model = YOLO('//cluster/home/ammaa/Downloads/Ammars/Models/YOLOv8/runs/classify/8x/weights/best.pt')
model.val()
# Out:
# Ultralytics YOLOv8.0.162 🚀 Python-3.11.4 torch-2.0.1 CUDA:0 (NVIDIA A100-PCIE-40GB, 40390MiB)
# YOLOv8x-cls summary (fused): 133 layers, 56128324 parameters, 0 gradients
# train: /cluster/home/ammaa/Downloads/Ammars/Models/PIM/FGVC-Multi/Split_500/train... found 1564 images in 4 classes ✅
# val: /cluster/home/ammaa/Downloads/Ammars/Models/PIM/FGVC-Multi/Split_500/val... found 80 images in 4 classes ✅
# test: /cluster/home/ammaa/Downloads/Ammars/Models/PIM/FGVC-Multi/Split_500/test... found 474 images in 4 classes ✅
# val: Scanning /cluster/home/ammaa/Downloads/Ammars/Models/PIM/FGVC-Multi/Split_5
# val: New cache created: /cluster/home/ammaa/Downloads/Ammars/Models/PIM/FGVC-Multi/Split_500/val.cache
# ...
